# %%
import pandas as pd
import numpy as np

# Load the first data (adjust path and skiprows if necessary)
data_1 = pd.read_csv("/Users/leo/Desktop/Projects/Data Log Analysis/Data/Wanbao+Red+SCRK_Steel+1100RPM.csv", skiprows=15)

# Remove the first row and columns with all NaN values
data_1 = data_1.drop(index=0)
data_1 = data_1.dropna(axis=1, how="all").loc[:, (data_1 != 0.0).any()]

# Function to remove columns with no change in values (constant columns)
def remove_constant_columns(df):
    # Remove columns where all values are the same
    return df.loc[:, df.nunique() > 1]

# Apply the function to remove constant columns
data_1 = remove_constant_columns(data_1)



# Display the cleaned data
data_1

# Load the second data (adjust path and skiprows if necessary)
data_2 = pd.read_csv("/Users/leo/Desktop/Projects/Data Log Analysis/Data/Wanbao+Red+SCRK_Alminium+1100RPM.csv", skiprows=15)

# Remove the first row and columns with all NaN values
data_2 = data_2.drop(index=0)
data_2 = data_2.dropna(axis=1, how="all").loc[:, (data_2 != 0.0).any()]

# Function to remove columns with no change in values (constant columns)
def remove_constant_columns(df):
    # Remove columns where all values are the same
    return df.loc[:, df.nunique() > 1]

# Apply the function to remove constant columns
data_2 = remove_constant_columns(data_2)



# Display the cleaned data
data_2
# Out:
#         Time  WBO2_AT_En  AFR_Target  T_Air   SA     RPM  TPS_AD  TPS_indx  \
# 1        0.0         1.0        12.7   38.0  6.0  1808.0    51.0       0.0
# 2      100.0         1.0        12.7   38.0  4.0  1835.0    50.0       0.0
# 3      200.0         1.0        12.7   38.0  4.0  1854.0    51.0       0.0
# 4      300.0         1.0        12.7   38.0  4.0  1894.0    51.0       0.0
# 5      400.0         1.0        12.7   38.0  4.0  1855.0    51.0       0.0
# ..       ...         ...         ...    ...  ...     ...     ...       ...
# 702  70100.0         1.0        12.6   36.0  5.0  2616.0    51.0       0.0
# 703  70200.0         1.0        12.7   36.0 -1.0  2385.0    51.0       0.0
# 704  70300.0         1.0        12.7   36.0  2.0  2112.0    51.0       0.0
# 705  70400.0         1.0        12.7   36.0  2.0  2025.0    51.0       0.0
# 706  70500.0         1.0        12.7   36.0  3.0  1958.0    51.0       0.0
#
#      Volt_Batt  Inj_Angle  ...  AFR_WBO2  Acc_Fuel_Mult  NBO2_AD  \
# 1         12.7        0.0  ...      12.7            0.0     78.0
# 2         12.7        0.0  ...      13.0            0.0     78.0
# 3         12.7        0.0  ...      12.9            0.0     78.0
# 4         12.7        0.0  ...      12.9            0.0     78.0
# 5         12.7        0.0  ...      12.8            0.0     78.0
# ..         ...        ...  ...       ...            ...      ...
# 702       12.7        0.0  ...      11.1            0.0     78.0
# 703       12.7        0.0  ...      11.2            0.0     78.0
# 704       12.7        0.0  ...      11.2            0.0     78.0
# 705       12.7        0.0  ...      11.0            0.0     78.0
# 706       12.8        0.0  ...      11.0            0.0     78.0
#
#      Cyl1_Final_VM  ISC_Air_Flow  Idle_Desir_RPM  Cyl1_Injector_Period_Rate  \
# 1            150.0         40.23          1808.0                       3.52
# 2            148.0         40.23          1808.0                       3.52
# 3            148.0         40.23          1808.0                       3.52
# 4            144.0         40.23          1808.0                       3.52
# 5            144.0         40.23          1808.0                       3.52
# ..             ...           ...             ...                        ...
# 702          146.0         40.23          2096.0                       5.08
# 703          154.0         40.23          2016.0                       5.08
# 704          156.0         40.23          1856.0                       4.30
# 705          152.0         40.23          1824.0                       3.91
# 706          150.0         40.23          1824.0                       3.91
#
#      TimeCount  PH_GPS_Altitude  PH_GPS_Speed
# 1        968.8             10.2           0.0
# 2         62.5             10.2           0.0
# 3        164.1             10.2           0.0
# 4        359.4             10.2           0.0
# 5        453.1             10.2           0.0
# ..         ...              ...           ...
# 702      570.3             13.3          21.0
# 703      671.9             13.3          21.0
# 704      765.6             13.3          21.0
# 705      867.2             13.3          21.0
# 706      960.9             13.3          21.0
#
# [706 rows x 25 columns]

# %%
col_name = 'TPS_Percent'  # Replace with your actual column name

# Find the first index where the column value is non-zero
first_nonzero_index = (data_1[col_name] != 0.0).idxmax()

# Slice the data from the first non-zero occurrence
data_after_first_nonzero = data_1.loc[first_nonzero_index:]

# Find the first occurrence of 0.0 after the initial non-zero value
first_zero_after_nonzero_index = data_after_first_nonzero[data_after_first_nonzero[col_name] == 0.0].index.min()

# Extract the section of data between first nonzero and when it returns to 0.0
if pd.notna(first_zero_after_nonzero_index):  # Ensure a valid index is found
    data_section_1 = data_1.loc[first_nonzero_index-50:first_zero_after_nonzero_index+50].reset_index(drop=True)
    print("Extracted data section:")
    print(data_section_1)
else:
    print("No return to 0.0 found. Using data from first nonzero onward.")
    data_section_1 = data_1.loc[first_nonzero_index:].reset_index(drop=True)

# Save the extracted section to a CSV
data_section_1
# Out:
# Extracted data section:
#         Time  Dec_FC_En  AFR_Target  T_Air    SA     RPM  TPS_AD  TPS_indx  \
# 0    10800.0        0.0        12.8   30.0   4.0  1844.0   140.0       0.0
# 1    10900.0        0.0        12.8   30.0   7.0  1833.0   140.0       0.0
# 2    11000.0        0.0        12.8   30.0   7.0  1800.0   139.0       0.0
# 3    11100.0        0.0        12.8   30.0   6.0  1885.0   140.0       0.0
# 4    11200.0        0.0        12.8   30.0   6.0  1816.0   139.0       0.0
# ..       ...        ...         ...    ...   ...     ...     ...       ...
# 564  67200.0        1.0        12.8   32.0  30.0  6175.0   140.0       0.0
# 565  67300.0        1.0        12.8   32.0  30.0  6105.0   140.0       0.0
# 566  67400.0        1.0        12.8   32.0  30.0  6105.0   140.0       0.0
# 567  67500.0        1.0        12.8   32.0  30.0  6026.0   140.0       0.0
# 568  67600.0        1.0        12.8   32.0  30.0  6026.0   140.0       0.0
#
#      Volt_Batt  Inj_Angle  ...  Avg_Fuel_Consump  Acc_Fuel_Mult  NBO2_AD  \
# 0         12.9        0.0  ...              0.07            0.0     79.0
# 1         12.8        0.0  ...              0.07            0.0     78.0
# 2         12.9        0.0  ...              0.07            0.0     79.0
# 3         12.8        0.0  ...              0.07            0.0     78.0
# 4         12.8        0.0  ...              0.07            0.0     78.0
# ..         ...        ...  ...               ...            ...      ...
# 564       12.8        0.0  ...              0.01            0.0     78.0
# 565       12.8        0.0  ...              0.01            0.0     78.0
# 566       12.8        0.0  ...              0.01            0.0     78.0
# 567       12.8        0.0  ...              0.01            0.0     79.0
# 568       12.8        0.0  ...              0.01            0.0     79.0
#
#      Cyl1_Final_VM  ISC_Air_Flow  Idle_Desir_RPM  Cyl1_Injector_Period_Rate  \
# 0            178.0          5.47          1792.0                       4.69
# 1            176.0          5.47          1792.0                       4.69
# 2            176.0          5.47          1792.0                       4.69
# 3            180.0          5.47          1792.0                       4.69
# 4            176.0          5.47          1792.0                       4.69
# ..             ...           ...             ...                        ...
# 564          146.0          5.47          2096.0                       0.00
# 565          146.0          5.47          2096.0                       0.00
# 566          146.0          5.47          2096.0                       0.00
# 567          144.0          5.47          2096.0                       0.00
# 568          144.0          5.47          2096.0                       0.00
#
#      TimeCount  PH_GPS_Altitude  PH_GPS_Speed
# 0        375.0             18.2           0.0
# 1        476.6             18.2           0.0
# 2        570.3             18.2           0.0
# 3        671.9             18.2           0.0
# 4        765.6             18.2           0.0
# ..         ...              ...           ...
# 564       15.6             20.2          85.0
# 565      210.9             20.2          85.0
# 566      210.9             20.2          85.0
# 567      406.2             20.2          85.0
# 568      406.2             20.1          78.0
#
# [569 rows x 25 columns]
#         Time  Dec_FC_En  AFR_Target  T_Air    SA     RPM  TPS_AD  TPS_indx  \
# 0    10800.0        0.0        12.8   30.0   4.0  1844.0   140.0       0.0
# 1    10900.0        0.0        12.8   30.0   7.0  1833.0   140.0       0.0
# 2    11000.0        0.0        12.8   30.0   7.0  1800.0   139.0       0.0
# 3    11100.0        0.0        12.8   30.0   6.0  1885.0   140.0       0.0
# 4    11200.0        0.0        12.8   30.0   6.0  1816.0   139.0       0.0
# ..       ...        ...         ...    ...   ...     ...     ...       ...
# 564  67200.0        1.0        12.8   32.0  30.0  6175.0   140.0       0.0
# 565  67300.0        1.0        12.8   32.0  30.0  6105.0   140.0       0.0
# 566  67400.0        1.0        12.8   32.0  30.0  6105.0   140.0       0.0
# 567  67500.0        1.0        12.8   32.0  30.0  6026.0   140.0       0.0
# 568  67600.0        1.0        12.8   32.0  30.0  6026.0   140.0       0.0
#
#      Volt_Batt  Inj_Angle  ...  Avg_Fuel_Consump  Acc_Fuel_Mult  NBO2_AD  \
# 0         12.9        0.0  ...              0.07            0.0     79.0
# 1         12.8        0.0  ...              0.07            0.0     78.0
# 2         12.9        0.0  ...              0.07            0.0     79.0
# 3         12.8        0.0  ...              0.07            0.0     78.0
# 4         12.8        0.0  ...              0.07            0.0     78.0
# ..         ...        ...  ...               ...            ...      ...
# 564       12.8        0.0  ...              0.01            0.0     78.0
# 565       12.8        0.0  ...              0.01            0.0     78.0
# 566       12.8        0.0  ...              0.01            0.0     78.0
# 567       12.8        0.0  ...              0.01            0.0     79.0
# 568       12.8        0.0  ...              0.01            0.0     79.0
#
#      Cyl1_Final_VM  ISC_Air_Flow  Idle_Desir_RPM  Cyl1_Injector_Period_Rate  \
# 0            178.0          5.47          1792.0                       4.69
# 1            176.0          5.47          1792.0                       4.69
# 2            176.0          5.47          1792.0                       4.69
# 3            180.0          5.47          1792.0                       4.69
# 4            176.0          5.47          1792.0                       4.69
# ..             ...           ...             ...                        ...
# 564          146.0          5.47          2096.0                       0.00
# 565          146.0          5.47          2096.0                       0.00
# 566          146.0          5.47          2096.0                       0.00
# 567          144.0          5.47          2096.0                       0.00
# 568          144.0          5.47          2096.0                       0.00
#
#      TimeCount  PH_GPS_Altitude  PH_GPS_Speed
# 0        375.0             18.2           0.0
# 1        476.6             18.2           0.0
# 2        570.3             18.2           0.0
# 3        671.9             18.2           0.0
# 4        765.6             18.2           0.0
# ..         ...              ...           ...
# 564       15.6             20.2          85.0
# 565      210.9             20.2          85.0
# 566      210.9             20.2          85.0
# 567      406.2             20.2          85.0
# 568      406.2             20.1          78.0
#
# [569 rows x 25 columns]

# %%
col_name = 'TPS_Percent'  # Replace with your actual column name

# Find the first index where the column value is non-zero
first_nonzero_index = (data_2[col_name] != 0.0).idxmax()

# Slice the data from the first non-zero occurrence
data_after_first_nonzero = data_2.loc[first_nonzero_index:]

# Find the first occurrence of 0.0 after the initial non-zero value
first_zero_after_nonzero_index = data_after_first_nonzero[data_after_first_nonzero[col_name] == 0.0].index.min()

# Extract the section of data between first nonzero and when it returns to 0.0
if pd.notna(first_zero_after_nonzero_index):  # Ensure a valid index is found
    data_section_2 = data_2.loc[first_nonzero_index-50:first_zero_after_nonzero_index+50].reset_index(drop=True)
    print("Extracted data section:")
    print(data_section_2)
else:
    print("No return to 0.0 found. Using data from first nonzero onward.")
    data_section_2 = data_2.loc[first_nonzero_index:].reset_index(drop=True)

# Save the extracted section to a CSV
data_section_2
# Out:
# Extracted data section:
#         Time  WBO2_AT_En  AFR_Target  T_Air    SA     RPM  TPS_AD  TPS_indx  \
# 0     3600.0         1.0        12.7   38.0   4.0  1890.0    51.0       0.0
# 1     3700.0         1.0        12.7   38.0   5.0  1837.0    52.0       0.0
# 2     3800.0         1.0        12.7   38.0   5.0  1826.0    51.0       0.0
# 3     3900.0         1.0        12.7   38.0   5.0  1806.0    51.0       0.0
# 4     4000.0         1.0        12.7   38.0   5.0  1894.0    51.0       0.0
# ..       ...         ...         ...    ...   ...     ...     ...       ...
# 308  34400.0         0.0        12.1   36.0  30.0  6137.0    55.0       1.0
# 309  34500.0         0.0        12.1   36.0  30.0  6150.0    59.0       2.0
# 310  34600.0         0.0        12.3   36.0  30.0  6250.0   161.0      27.0
# 311  34700.0         1.0        12.1   36.0  30.0  6651.0   308.0      64.0
# 312  34800.0         1.0        12.1   36.0  30.0  6983.0   386.0      83.0
#
#      Volt_Batt  Inj_Angle  ...  AFR_WBO2  Acc_Fuel_Mult  NBO2_AD  \
# 0         12.7        0.0  ...      13.1          0.000     78.0
# 1         12.7        0.0  ...      13.0          0.000     78.0
# 2         12.7        0.0  ...      13.1          0.000     78.0
# 3         12.8        0.0  ...      13.1          0.000     78.0
# 4         12.7        0.0  ...      13.0          0.000     78.0
# ..         ...        ...  ...       ...            ...      ...
# 308       12.5        0.0  ...      13.9          0.000     79.0
# 309       12.5        0.0  ...      14.1          0.000     78.0
# 310       12.5        0.0  ...      12.9          0.031     78.0
# 311       12.5        0.0  ...      12.5          0.047     79.0
# 312       12.5        0.0  ...      11.9          0.047     79.0
#
#      Cyl1_Final_VM  ISC_Air_Flow  Idle_Desir_RPM  Cyl1_Injector_Period_Rate  \
# 0            144.0         40.23          1808.0                       3.52
# 1            144.0         40.23          1808.0                       3.52
# 2            148.0         40.23          1808.0                       3.52
# 3            148.0         40.23          1808.0                       3.52
# 4            144.0         40.23          1808.0                       3.52
# ..             ...           ...             ...                        ...
# 308          139.0         40.23          2096.0                       8.98
# 309          137.0         40.23          2096.0                       8.59
# 310          169.0         40.23          2096.0                      12.50
# 311          206.0         40.23          2096.0                      21.88
# 312          225.0         40.23          2096.0                      27.73
#
#      TimeCount  PH_GPS_Altitude  PH_GPS_Speed
# 0        679.7             11.5           1.0
# 1        773.4             11.5           1.0
# 2        875.0             11.5           1.0
# 3        968.8             11.5           1.0
# 4         70.3             11.9           0.0
# ..         ...              ...           ...
# 308      632.8             13.3          84.0
# 309      734.4             13.3          84.0
# 310      828.1             13.3          84.0
# 311      929.7             13.3          84.0
# 312       23.4             13.6          78.0
#
# [313 rows x 25 columns]
#         Time  WBO2_AT_En  AFR_Target  T_Air    SA     RPM  TPS_AD  TPS_indx  \
# 0     3600.0         1.0        12.7   38.0   4.0  1890.0    51.0       0.0
# 1     3700.0         1.0        12.7   38.0   5.0  1837.0    52.0       0.0
# 2     3800.0         1.0        12.7   38.0   5.0  1826.0    51.0       0.0
# 3     3900.0         1.0        12.7   38.0   5.0  1806.0    51.0       0.0
# 4     4000.0         1.0        12.7   38.0   5.0  1894.0    51.0       0.0
# ..       ...         ...         ...    ...   ...     ...     ...       ...
# 308  34400.0         0.0        12.1   36.0  30.0  6137.0    55.0       1.0
# 309  34500.0         0.0        12.1   36.0  30.0  6150.0    59.0       2.0
# 310  34600.0         0.0        12.3   36.0  30.0  6250.0   161.0      27.0
# 311  34700.0         1.0        12.1   36.0  30.0  6651.0   308.0      64.0
# 312  34800.0         1.0        12.1   36.0  30.0  6983.0   386.0      83.0
#
#      Volt_Batt  Inj_Angle  ...  AFR_WBO2  Acc_Fuel_Mult  NBO2_AD  \
# 0         12.7        0.0  ...      13.1          0.000     78.0
# 1         12.7        0.0  ...      13.0          0.000     78.0
# 2         12.7        0.0  ...      13.1          0.000     78.0
# 3         12.8        0.0  ...      13.1          0.000     78.0
# 4         12.7        0.0  ...      13.0          0.000     78.0
# ..         ...        ...  ...       ...            ...      ...
# 308       12.5        0.0  ...      13.9          0.000     79.0
# 309       12.5        0.0  ...      14.1          0.000     78.0
# 310       12.5        0.0  ...      12.9          0.031     78.0
# 311       12.5        0.0  ...      12.5          0.047     79.0
# 312       12.5        0.0  ...      11.9          0.047     79.0
#
#      Cyl1_Final_VM  ISC_Air_Flow  Idle_Desir_RPM  Cyl1_Injector_Period_Rate  \
# 0            144.0         40.23          1808.0                       3.52
# 1            144.0         40.23          1808.0                       3.52
# 2            148.0         40.23          1808.0                       3.52
# 3            148.0         40.23          1808.0                       3.52
# 4            144.0         40.23          1808.0                       3.52
# ..             ...           ...             ...                        ...
# 308          139.0         40.23          2096.0                       8.98
# 309          137.0         40.23          2096.0                       8.59
# 310          169.0         40.23          2096.0                      12.50
# 311          206.0         40.23          2096.0                      21.88
# 312          225.0         40.23          2096.0                      27.73
#
#      TimeCount  PH_GPS_Altitude  PH_GPS_Speed
# 0        679.7             11.5           1.0
# 1        773.4             11.5           1.0
# 2        875.0             11.5           1.0
# 3        968.8             11.5           1.0
# 4         70.3             11.9           0.0
# ..         ...              ...           ...
# 308      632.8             13.3          84.0
# 309      734.4             13.3          84.0
# 310      828.1             13.3          84.0
# 311      929.7             13.3          84.0
# 312       23.4             13.6          78.0
#
# [313 rows x 25 columns]

# %%
import plotly.graph_objects as go

# Assuming 'data_section_2' is your DataFrame
x_col = 'Time'   # Column for X-axis
y_col1 = 'RPM'   # First column for Y-axis (range from 2000 to 10000)
y_col2 = 'PH_GPS_Speed'  # Second column for Y-axis (range from 0 to 100)
y_col3 = 'TPS_Percent'

# Create a figure
fig = go.Figure()

# Add the first plot (RPM) with the first Y-axis
fig.add_trace(go.Scatter(
    x=data_section_2[x_col], 
    y=data_section_2[y_col1], 
    mode='lines',  # 'lines+markers' for both lines and markers
    name=y_col1,  # Name for the legend
    line=dict(color='green', width=2),  # Line color and width
    marker=dict(symbol='circle', size=6)  # Marker style
))

# Add the second plot (PH_GPS_Speed) with the second Y-axis
fig.add_trace(go.Scatter(
    x=data_section_2[x_col], 
    y=data_section_2[y_col2], 
    mode='lines',  # 'lines+markers' for both lines and markers
    name=y_col2,  # Name for the legend
    line=dict(color='blue', width=2),  # Line color and width
    marker=dict(symbol='x', size=6),  # Marker style
    yaxis='y2'  # This specifies that the second axis should be used
))

# Add the third plot (Another_Column) with the third Y-axis
fig.add_trace(go.Scatter(
    x=data_section_2[x_col], 
    y=data_section_2[y_col3], 
    mode='lines',  # 'lines+markers' for both lines and markers
    name=y_col3,  # Name for the legend
    line=dict(color='red', width=2),  # Line color and width
    marker=dict(symbol='square', size=6),  # Marker style
    yaxis='y3'  # This specifies that the third axis should be used
))

# Update layout for better presentation
fig.update_layout(
    title="Comparison of RPM, GPS Speed, and Another Column",  # Title of the plot
    xaxis_title=x_col,  # X-axis label
    yaxis_title=y_col1,  # Left Y-axis label for RPM
    yaxis2=dict(
        title=y_col2,  # Right Y-axis label for PH_GPS_Speed
        overlaying='y',  # Share the same X-axis
        side='right'  # Place on the right side
    ),
    yaxis3=dict(
        title=y_col3,  # Right Y-axis label for Another_Column
        overlaying='y',  # Share the same X-axis
        side='right',  # Place on the right side (can adjust to left if needed)
        position=0.85  # Adjust position if needed to avoid overlap
    ),
    legend=dict(x=0.01, y=0.95, font=dict(size=8)),  # Position legend
    template='plotly_dark',  # Optional: Dark theme for the graph
    width=1200,  # Set width of the plot
    height=1000  # Set height of the plot
)

# Show the interactive plot
fig.show()

# %%
# Out:
# 87
#         Time  WBO2_AT_En  AFR_Target  T_Air   SA     RPM  TPS_AD  TPS_indx  \
# 0     3600.0         1.0        12.7   38.0  4.0  1890.0    51.0       0.0
# 1     3700.0         1.0        12.7   38.0  5.0  1837.0    52.0       0.0
# 2     3800.0         1.0        12.7   38.0  5.0  1826.0    51.0       0.0
# 3     3900.0         1.0        12.7   38.0  5.0  1806.0    51.0       0.0
# 4     4000.0         1.0        12.7   38.0  5.0  1894.0    51.0       0.0
# ..       ...         ...         ...    ...  ...     ...     ...       ...
# 665  70100.0         1.0        12.6   36.0  5.0  2616.0    51.0       0.0
# 666  70200.0         1.0        12.7   36.0 -1.0  2385.0    51.0       0.0
# 667  70300.0         1.0        12.7   36.0  2.0  2112.0    51.0       0.0
# 668  70400.0         1.0        12.7   36.0  2.0  2025.0    51.0       0.0
# 669  70500.0         1.0        12.7   36.0  3.0  1958.0    51.0       0.0
#
#      Volt_Batt  Inj_Angle  ...  AFR_WBO2  Acc_Fuel_Mult  NBO2_AD  \
# 0         12.7        0.0  ...      13.1            0.0     78.0
# 1         12.7        0.0  ...      13.0            0.0     78.0
# 2         12.7        0.0  ...      13.1            0.0     78.0
# 3         12.8        0.0  ...      13.1            0.0     78.0
# 4         12.7        0.0  ...      13.0            0.0     78.0
# ..         ...        ...  ...       ...            ...      ...
# 665       12.7        0.0  ...      11.1            0.0     78.0
# 666       12.7        0.0  ...      11.2            0.0     78.0
# 667       12.7        0.0  ...      11.2            0.0     78.0
# 668       12.7        0.0  ...      11.0            0.0     78.0
# 669       12.8        0.0  ...      11.0            0.0     78.0
#
#      Cyl1_Final_VM  ISC_Air_Flow  Idle_Desir_RPM  Cyl1_Injector_Period_Rate  \
# 0            144.0         40.23          1808.0                       3.52
# 1            144.0         40.23          1808.0                       3.52
# 2            148.0         40.23          1808.0                       3.52
# 3            148.0         40.23          1808.0                       3.52
# 4            144.0         40.23          1808.0                       3.52
# ..             ...           ...             ...                        ...
# 665          146.0         40.23          2096.0                       5.08
# 666          154.0         40.23          2016.0                       5.08
# 667          156.0         40.23          1856.0                       4.30
# 668          152.0         40.23          1824.0                       3.91
# 669          150.0         40.23          1824.0                       3.91
#
#      TimeCount  PH_GPS_Altitude  PH_GPS_Speed
# 0        679.7             11.5           1.0
# 1        773.4             11.5           1.0
# 2        875.0             11.5           1.0
# 3        968.8             11.5           1.0
# 4         70.3             11.9           0.0
# ..         ...              ...           ...
# 665      570.3             13.3          21.0
# 666      671.9             13.3          21.0
# 667      765.6             13.3          21.0
# 668      867.2             13.3          21.0
# 669      960.9             13.3          21.0
#
# [670 rows x 25 columns]

# %%
import plotly.graph_objects as go

# Assuming 'data_section_1' and 'data_section_2' are your DataFrames
x_col = 'Time'  # Column for X-axis
y_col1 = 'RPM'  # First column for Y-axis (range from 2000 to 10000)
y_col2 = 'PH_GPS_Speed'  # Second column for Y-axis (range from 0 to 100)
y_col3 = 'TPS_Percent'  # Third column for Y-axis

# Create a figure
fig = go.Figure()

# Add the first plot (RPM) for data_section_1 with the first Y-axis
fig.add_trace(go.Scatter(
    x=data_section_1[x_col], 
    y=data_section_1[y_col1], 
    mode='lines',  # 'lines+markers' for both lines and markers
    name=f"{y_col1} (Dataset 1)",  # Name for the legend
    line=dict(color='green', width=2),  # Line color and width
    marker=dict(symbol='circle', size=6)  # Marker style
))

# Add the second plot (RPM) for data_section_2 with the first Y-axis
fig.add_trace(go.Scatter(
    x=data_section_1[x_col], 
    y=data_section_2[y_col1], 
    mode='lines', 
    name=f"{y_col1} (Dataset 2)",  # Name for the legend
    line=dict(color='orange', width=2),  # Line color for comparison
    marker=dict(symbol='circle', size=6)  # Marker style
))

# Add the second plot (PH_GPS_Speed) for data_section_1 with the second Y-axis
fig.add_trace(go.Scatter(
    x=data_section_1[x_col], 
    y=data_section_1[y_col2], 
    mode='lines', 
    name=f"{y_col2} (Dataset 1)",  # Name for the legend
    line=dict(color='blue', width=2), 
    marker=dict(symbol='x', size=6),  
    yaxis='y2'  # This specifies that the second axis should be used
))

# Add the second plot (PH_GPS_Speed) for data_section_2 with the second Y-axis
fig.add_trace(go.Scatter(
    x=data_section_1[x_col], 
    y=data_section_2[y_col2], 
    mode='lines', 
    name=f"{y_col2} (Dataset 2)", 
    line=dict(color='cyan', width=2),  # Different color for comparison
    marker=dict(symbol='x', size=6),  
    yaxis='y2'  
))

# Add the third plot (TPS_Percent) for data_section_1 with the third Y-axis
fig.add_trace(go.Scatter(
    x=data_section_1[x_col], 
    y=data_section_1[y_col3], 
    mode='lines', 
    name=f"{y_col3} (Dataset 1)", 
    line=dict(color='red', width=2),  
    marker=dict(symbol='square', size=6),  
    yaxis='y3'  
))

# Add the third plot (TPS_Percent) for data_section_2 with the third Y-axis
fig.add_trace(go.Scatter(
    x=data_section_1[x_col], 
    y=data_section_2[y_col3], 
    mode='lines', 
    name=f"{y_col3} (Dataset 2)", 
    line=dict(color='magenta', width=2),  
    marker=dict(symbol='square', size=6),  
    yaxis='y3'  
))

# Update layout for better presentation
fig.update_layout(
    title="Comparison of RPM, GPS Speed, and TPS Percent for Two Datasets",  
    xaxis_title='Time',  # Set the X-axis label to 'Time'
    yaxis_title=f"{y_col1} (Dataset 1)",  # Label for left y-axis
    yaxis2=dict(
        title=f"{y_col2} (Right Axis)",  # Label for right y-axis
        overlaying='y',  # Share the same X-axis
        side='right'  # Place on the right side
    ),
    yaxis3=dict(
        title=f"{y_col3} (Right Axis 2)",  # Title for third y-axis
        overlaying='y',  # Share the same X-axis
        side='right',  # Place on the right side (can adjust to left if needed)
        position=0.85  # Adjust position if needed to avoid overlap
    ),
    legend=dict(x=0.01, y=0.99, font=dict(size=10)),  # Increase the font size for better readability
    template='plotly_dark',  # Optional: Dark theme for the graph
    width=1800,  # Set width of the plot
    height=1000  # Set height of the plot
)

# Show the interactive plot
fig.show()
